# %%
import seaborn as sns
import matplotlib as plt

df = pd.read_csv('Stud_perf.csv')
df
# Out:
#    Unnamed: 0   Name  Gender Class  Subject  Marks
# 0           0   John    Male   10A     Math     78
# 1           1  Sarah  Female   10A     Math     92
# 2           2   Mike    Male   10B  Science     45
# 3           3   Lira  Female   10A  English     88
# 4           4  Peter    Male   10B     Math     67
# 5           5  Faith  Female   10C  Science     73

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='Gender', y='Marks', color='blue', data=df)
plt.title('gender of stdnt vs marks')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Subject', y='Marks', color='gold', data=df)
plt.title('Sbj vs Marks of student')
plt.show()

# %%
# Out:
#   Cell In[21], line 1
#     top student = df[df['MARKS'] ==df['Marks'].max()]
#         ^
# SyntaxError: invalid syntax
